# %% [markdown]
# # 1. Simple Statistics and NLTK
#
# The following exercises use a portion of the Gutenberg corpus that is stored in the corpus dataset of NLTK. [The Project Gutenberg](http://www.gutenberg.org/) is a large collection of electronic books that are out of copyright. These books are free to download for reading, or for our case, for doing a little of corpus analysis.
#
# To obtain the list of files of NLTK's Gutenberg corpus, type the following commands:

# %%
import nltk
nltk.download('gutenberg')
nltk.corpus.gutenberg.fileids()
# Out:
# [nltk_data] Downloading package gutenberg to /Users/noah/nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %% [markdown]
# To obtain all words in the entire Gutenberg corpus of NLTK, type the following:

# %%
 gutenbergwords= nltk.corpus.gutenberg.words()

# %% [markdown]
# Now I can find the total number of words, and the first 10 words (if i attempt to display all the words computer will be freeze):

# %%
len(gutenbergwords)
# Out:
# 2621613

# %%
gutenbergwords[:10]
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', 'VOLUME', 'I', 'CHAPTER']

# %% [markdown]
# I can also find the words of just a selection of documents, as shown below.
# More details of what information I can extract from this corpus: read the "Gutenberg corpus" section of the [NLTK book chapter 2](http://www.nltk.org/book_1ed/ch02.html), section 2.1.

# %%
emma = nltk.corpus.gutenberg.words('austen-emma.txt')
len(emma)
# Out:
# 192427

# %%
emma[:10]
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', 'VOLUME', 'I', 'CHAPTER']

# %% [markdown]
# I can use Python's `collections.Counter` to find the most frequent words of a document from NLTK's Gutenberg collection.
# Below : how I can find the 5 most frequent words of the word list stored in the variable `emma`:

# %%
import collections
emma_counter = collections.Counter(emma)
print(emma_counter.most_common(5))
# Out:
# [(',', 11454), ('.', 6928), ('to', 5183), ('the', 4844), ('and', 4672)]

# %% [markdown]
# ### Exercise 1.1
# *Write Python code that prints the 10 most frequent words in each of the documents of the Gutenberg corpus. Can identify any similarities among these list of most frequent words?*

# %%
for i in nltk.corpus.gutenberg.fileids():
    j=nltk.corpus.gutenberg.words(i)
    print(i)
    print(collections.Counter(j).most_common(10))
# Out:
# austen-emma.txt
# [(',', 11454), ('.', 6928), ('to', 5183), ('the', 4844), ('and', 4672), ('of', 4279), ('I', 3178), ('a', 3004), ('was', 2385), ('her', 2381)]
# austen-persuasion.txt
# [(',', 6750), ('the', 3120), ('to', 2775), ('.', 2741), ('and', 2739), ('of', 2564), ('a', 1529), ('in', 1346), ('was', 1330), (';', 1290)]
# austen-sense.txt
# [(',', 9397), ('to', 4063), ('.', 3975), ('the', 3861), ('of', 3565), ('and', 3350), ('her', 2436), ('a', 2043), ('I', 2004), ('in', 1904)]
# bible-kjv.txt
# [(',', 70509), ('the', 62103), (':', 43766), ('and', 38847), ('of', 34480), ('.', 26160), ('to', 13396), ('And', 12846), ('that', 12576), ('in', 12331)]
# blake-poems.txt
# [(',', 680), ('the', 351), ('.', 201), ('And', 176), ('and', 169), ('of', 131), ('I', 130), ('in', 116), ('a', 108), ("'", 104)]
# bryant-stories.txt
# [(',', 3481), ('the', 3086), ('and', 1873), ('.', 1817), ('to', 1165), ('a', 988), ('"', 900), ('he', 872), ('of', 801), ('was', 706)]
# burgess-busterbrown.txt
# ...

# %%
import nltk
nltk.pos_tag([",",'.','the','to','and'])
# similarity
# the first two ,,. are not words at all but punctuation marks
# Out:
# [(',', ','), ('.', '.'), ('the', 'DT'), ('to', 'TO'), ('and', 'CC')]

# %% [markdown]
# ### Exercise 1.2
# *Find the unique words with length of more than 17 characters in the complete Gutenberg corpus.*
#
# *Hint: to find the distinct items of a Python list you can convert it into a set:*

# %%
my_list = ['a','b','c','a','c']
my_set = set(my_list)
print(my_set)
print(len(my_set))
# Out:
# {'c', 'a', 'b'}
# 3

# %%
guten_set=set(gutenbergwords)
# print(guten_set)
guten_list=[]
for i in guten_set:
    if len(i)>17:
        guten_list.append(i)
print(len(guten_list))
print(sorted(guten_list,key=str.lower))

# words = set([w for w in nltk.corpus.gutenberg.words() if len(w) > 17])
# print(len(words))
# print(words)
# Out:
# 3
# ['characteristically', 'Mahershalalhashbaz', 'uninterpenetratingly']

# %% [markdown]
# ### Exercise 1.3
# *Find the words that are longer than 5 characters and occur more than 2000 times in the complete Gutenberg corpus.*

# %%
guten_list_20=[]
for i in guten_set:
#     if len(i)>5 and collections.Counter(i)>2000:
    if len(i)>5:
        guten_list_20.append(i)
print(guten_list_20)
# Out:
# ['Impudence', 'farthing', 'Raddai', 'keystone', 'misrule', 'Unshored', 'Turning', 'hauiour', 'warehouses', 'impassive', 'kindness', 'reviewed', 'vomited', 'Hearke', 'kelson', 'Thewes', 'droops', 'deadreckoning', 'description', 'bivouacks', 'heightening', 'Marmion', 'Assistant', 'brewed', 'asleepe', 'Gainst', 'climax', 'Ambergriese', 'undiscriminating', 'Bethesda', 'Gigantic', 'proposal', 'CIVILITY', 'stubbornly', 'imperial', 'Shechaniah', 'ingeniously', 'slacked', 'remember', 'persist', 'chirping', 'Bacchus', 'returne', 'perplexity', 'require', 'steads', 'Colney', 'trespassers', 'Astley', 'Spitzbergen', 'skrimmage', 'confab', 'PIERCEFIELD', 'bandana', 'concentring', 'Faults', 'soberly', 'Zaccai', 'Ephraimites', 'insurrection', 'smitest', 'Augustus', 'addressed', 'stammered', 'consequential', 'Divides', 'smacking', 'resemblance', 'exhaustion', 'Rinnah', 'sipping', 'Baalperazim', 'engraving', 'unfallen', 'sagged', 'ulceration', 'masques', 'GAZING', 'prescient', 'repealed', 'Inland', 'd
# ...

# %%
guten_list_20_2=[]
my_collection=collections.Counter(gutenbergwords)
for i in guten_list_20:
    if my_collection[i]>2000:
        guten_list_20_2.append(i)
print(guten_list_20_2)
# Out:
# ['Israel', 'before', 'children', 'people', 'against', 'should', 'little']

# %%
collections.Counter(gutenbergwords)
# Out:
# Counter({'[': 115,
#          'Emma': 866,
#          'by': 8012,
#          'Jane': 303,
#          'Austen': 3,
#          '1816': 1,
#          ']': 105,
#          'VOLUME': 3,
#          'I': 30221,
#          'CHAPTER': 291,
#          'Woodhouse': 313,
#          ',': 186091,
#          'handsome': 130,
#          'clever': 74,
#          'and': 78846,
#          'rich': 231,
#          'with': 16827,
#          'a': 32504,
#          'comfortable': 108,
#          'home': 677,
#          'happy': 537,
#          'disposition': 73,
#          'seemed': 1083,
#          'to': 46443,
#          'unite': 17,
#          'some': 2560,
#          'of': 70078,
#          'the': 125748,
#          'best': 574,
#          'blessings': 24,
#          'existence': 47,
#          ';': 27329,
#          'had': 10177,
#          'lived': 260,
#          'nearly': 137,
#          'twenty': 459,
#          '-': 8850,
#          'one': 5755,
#          'years': 1011,
#          'in': 31959,
# ...

# %% [markdown]
# ### Exercise 1.4
# *Find the average number of words in the documents of the NLTK Gutenberg corpus.*

# %%
len(gutenbergwords)/len(nltk.corpus.gutenberg.fileids())
# Out:
# 145645.16666666666

# %% [markdown]
# ### Exercise 1.5
# *Find the Gutenberg document that has the longest average word length.*

# %%
guten_dict={}
for i in nltk.corpus.gutenberg.fileids():
    j=nltk.corpus.gutenberg.words(i)
#     print(len(set(j)))
    guten_dict[i]=len(j)/len(set(j))
#     print(len(nltk.corpus.gutenberg.words(i)))
print(guten_dict)
# Out:
# {'austen-emma.txt': 24.63538599411087, 'austen-persuasion.txt': 16.00962165688193, 'austen-sense.txt': 20.719449729255086, 'bible-kjv.txt': 73.40068269300603, 'blake-poems.txt': 4.59010989010989, 'bryant-stories.txt': 12.57081447963801, 'burgess-busterbrown.txt': 10.75, 'carroll-alice.txt': 11.309681697612731, 'chesterton-ball.txt': 10.841175813121717, 'chesterton-brown.txt': 10.37028557657549, 'chesterton-thursday.txt': 10.167915381225209, 'edgeworth-parents.txt': 21.960075054727405, 'melville-moby_dick.txt': 13.502044830977896, 'milton-paradise.txt': 9.00613896381732, 'shakespeare-caesar.txt': 7.256460674157303, 'shakespeare-hamlet.txt': 6.858821369561227, 'shakespeare-macbeth.txt': 5.760517799352751, 'whitman-leaves.txt': 10.809058552585665}

# %%
longest_one=''
longest_length=0
for i in guten_dict:
    if guten_dict[i]>longest_length:
        longest_one=i
        longest_length=guten_dict[i]
print('Document with largest average word length is '+longest_one+' with word length '+str(longest_length))
# Out:
# Document with largest average word length is bible-kjv.txt with word length 73.40068269300603

# %%
average_word_lengths = dict()
for f in nltk.corpus.gutenberg.fileids():
    nchars = len(nltk.corpus.gutenberg.raw(f))
    nwords = len(nltk.corpus.gutenberg.words(f))
    average_word_lengths[f] = nchars/nwords
    # print("Document:", f, "Average word length:", average_word_lengths[f])

sorted_keys = sorted(average_word_lengths.keys(), key=lambda x: average_word_lengths[x], reverse=True)
print("Document with largest average word length is", sorted_keys[0], 
      "with word length", average_word_lengths[sorted_keys[0]])
# Out:
# Document with largest average word length is milton-paradise.txt with word length 4.835734572682675

# %% [markdown]
# ### Exercise 1.6
# *Find the 10 most frequent bigrams in the entire Gutenberg corpus.*

# %%
gutenbergwords= nltk.corpus.gutenberg.words()
gutenbergwords
# Out:
# ['[', 'Emma', 'by', 'Jane', 'Austen', '1816', ']', ...]

# %%
bigramsNLTK=nltk.bigrams(gutenbergwords)
bigrams_counter = collections.Counter(bigramsNLTK)
bigrams_counter.most_common(10)
# Out:
# [((',', 'and'), 41294),
#  (('of', 'the'), 18912),
#  (('in', 'the'), 9793),
#  (("'", 's'), 9781),
#  ((';', 'and'), 7559),
#  (('and', 'the'), 6432),
#  (('the', 'LORD'), 5964),
#  ((',', 'the'), 5957),
#  ((',', 'I'), 5677),
#  ((',', 'that'), 5352)]

# %% [markdown]
# ### Exercise 1.7
# *Find the most frequent bigram that begins with "Moby" in Herman Melville's "Moby Dick".*

# %%
mobydick = nltk.corpus.gutenberg.words('melville-moby_dick.txt')
bigramsNLTKmoby=nltk.bigrams(mobydick)

bigramsNLTKmobyWithMoby=[]
for i in list(bigramsNLTKmoby):
    if i[0]=='Moby':
        bigramsNLTKmobyWithMoby.append(i)
bigramsNLTKmobyWithMoby
bigrams_counterMoby = collections.Counter(bigramsNLTKmobyWithMoby)
bigrams_counterMoby
# Out:
# Counter({('Moby', 'Dick'): 83, ('Moby', '-'): 1})

# %% [markdown]
# # 2. Text Preprocessing with NLTK
# The following exercises will ask questions about tokens, stems, and parts of speech.
#
# ### Exercise 2.1
# *What is the sentence with the largest number of tokens in Austen's "Emma"?*

# %%
emma = nltk.corpus.gutenberg.raw('austen-emma.txt')

# %%
emma
# Out:
# '[Emma by Jane Austen 1816]\n\nVOLUME I\n\nCHAPTER I\n\n\nEmma Woodhouse, handsome, clever, and rich, with a comfortable home\nand happy disposition, seemed to unite some of the best blessings\nof existence; and had lived nearly twenty-one years in the world\nwith very little to distress or vex her.\n\nShe was the youngest of the two daughters of a most affectionate,\nindulgent father; and had, in consequence of her sister\'s marriage,\nbeen mistress of his house from a very early period.  Her mother\nhad died too long ago for her to have more than an indistinct\nremembrance of her caresses; and her place had been supplied\nby an excellent woman as governess, who had fallen little short\nof a mother in affection.\n\nSixteen years had Miss Taylor been in Mr. Woodhouse\'s family,\nless as a governess than a friend, very fond of both daughters,\nbut particularly of Emma.  Between _them_ it was more the intimacy\nof sisters.  Even before Miss Taylor had ceased to hold the nominal\noffice
# ...

# %%
emma_sent=nltk.sent_tokenize(emma)
emma_sent
# Out:
# ['[Emma by Jane Austen 1816]\n\nVOLUME I\n\nCHAPTER I\n\n\nEmma Woodhouse, handsome, clever, and rich, with a comfortable home\nand happy disposition, seemed to unite some of the best blessings\nof existence; and had lived nearly twenty-one years in the world\nwith very little to distress or vex her.',
#  "She was the youngest of the two daughters of a most affectionate,\nindulgent father; and had, in consequence of her sister's marriage,\nbeen mistress of his house from a very early period.",
#  'Her mother\nhad died too long ago for her to have more than an indistinct\nremembrance of her caresses; and her place had been supplied\nby an excellent woman as governess, who had fallen little short\nof a mother in affection.',
#  "Sixteen years had Miss Taylor been in Mr. Woodhouse's family,\nless as a governess than a friend, very fond of both daughters,\nbut particularly of Emma.",
#  'Between _them_ it was more the intimacy\nof sisters.',
# ...

# %%
longest=''
length=0
for i in emma_sent:
    if len(nltk.word_tokenize(i))>length:
        length=len(nltk.word_tokenize(i))
        longest=i
print('The longest sentence is '+longest+'\nThe length is '+str(length))
# Out:
# The longest sentence is While he lived, it must be only an engagement;
# but she flattered herself, that if divested of the danger of
# drawing her away, it might become an increase of comfort to him.--
# How to do her best by Harriet, was of more difficult decision;--
# how to spare her from any unnecessary pain; how to make
# her any possible atonement; how to appear least her enemy?--
# On these subjects, her perplexity and distress were very great--
# and her mind had to pass again and again through every bitter
# reproach and sorrowful regret that had ever surrounded it.--
# She could only resolve at last, that she would still avoid a
# meeting with her, and communicate all that need be told by letter;
# that it would be inexpressibly desirable to have her removed just
# now for a time from Highbury, and--indulging in one scheme more--
# nearly resolve, that it might be practicable to get an invitation
# for her to Brunswick Square.--Isabella had been pleased with Harriet;
# ...

# %% [markdown]
# ### Exercise 2.2
# *What are the 5 most frequent parts of speech in Austen's "Emma"? Use the universal tag set*

# %%
nltk.download('averaged_perceptron_tagger')
import collections
emma_sents = [nltk.word_tokenize(s) for s in nltk.sent_tokenize(nltk.corpus.gutenberg.raw('austen-emma.txt'))]
emma_tagged_sents = nltk.pos_tag_sents(emma_sents, tagset="universal")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/noah/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %% [markdown]
# An alternative implementation that uses `nltk.pos_tag` instead of `nltk.pos_tag_sents`:

# %%
nltk.download('averaged_perceptron_tagger')
import collections
emma_sents = [nltk.word_tokenize(s) for s in nltk.sent_tokenize(nltk.corpus.gutenberg.raw('austen-emma.txt'))]
emma_tagged_sents = [nltk.pos_tag(s, tagset="universal") for s in emma_sents]
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/noah/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
emma_tagged_sents
# Out:
# [[('[', 'NOUN'),
#   ('Emma', 'NOUN'),
#   ('by', 'ADP'),
#   ('Jane', 'NOUN'),
#   ('Austen', 'NOUN'),
#   ('1816', 'NUM'),
#   (']', 'NOUN'),
#   ('VOLUME', 'NOUN'),
#   ('I', 'PRON'),
#   ('CHAPTER', 'VERB'),
#   ('I', 'PRON'),
#   ('Emma', 'NOUN'),
#   ('Woodhouse', 'NOUN'),
#   (',', '.'),
#   ('handsome', 'NOUN'),
#   (',', '.'),
#   ('clever', 'NOUN'),
#   (',', '.'),
#   ('and', 'CONJ'),
#   ('rich', 'ADJ'),
#   (',', '.'),
#   ('with', 'ADP'),
#   ('a', 'DET'),
#   ('comfortable', 'ADJ'),
#   ('home', 'NOUN'),
#   ('and', 'CONJ'),
#   ('happy', 'ADJ'),
#   ('disposition', 'NOUN'),
#   (',', '.'),
#   ('seemed', 'VERB'),
#   ('to', 'PRT'),
#   ('unite', 'VERB'),
#   ('some', 'DET'),
#   ('of', 'ADP'),
#   ('the', 'DET'),
#   ('best', 'ADJ'),
#   ('blessings', 'NOUN'),
#   ('of', 'ADP'),
#   ('existence', 'NOUN'),
#   (';', '.'),
#   ('and', 'CONJ'),
#   ('had', 'VERB'),
#   ('lived', 'VERB'),
#   ('nearly', 'ADV'),
#   ('twenty-one', 'NUM'),
#   ('years', 'NOUN'),
# ...

# %%
emma_pos = []
for s in emma_tagged_sents:
    for w in s:
        emma_pos.append(w[1])
counter = collections.Counter(emma_pos)
counter.most_common(5)
# Out:
# [('VERB', 35721),
#  ('NOUN', 32000),
#  ('.', 30300),
#  ('PRON', 21263),
#  ('ADP', 17880)]

# %% [markdown]
# ### Exercise 2.3
# *What is the number of distinct stems in Austen's "Emma"?*

# %%
stemmer = nltk.PorterStemmer()
stems = set()
for s in emma_sents:
    for w in s:
        stems.add(stemmer.stem(w))
print("Austen's Emma has %i distinct stems" % len(stems))
# Out:
# Austen's Emma has 5367 distinct stems

# %% [markdown]
# ###  Exercise 2.4
# *What is the most ambiguous stem in Austen's "Emma"? (meaning, which stem in Austen's "Emma" is realised in the largest number of distinct tokens?)*

# %%
# 1. Group all words by their stem
stemmer = nltk.PorterStemmer()
stem_sets = dict()
for s in emma_sents:
    for w in s:
        stemmed = stemmer.stem(w)
        if stemmed not in stem_sets:
            stem_sets[stemmed] = set([w])
        else:
            stem_sets[stemmed].add(w)
            
# 2. Find most ambiguous stem
most_ambiguous = None
number_stems = 0
for k in stem_sets:
    if len(stem_sets[k]) > number_stems:
        number_stems = len(stem_sets[k])
        most_ambiguous = (k, stem_sets[k])
        
print("The most ambiguous stem is '%s' with words %s" % (most_ambiguous[0], most_ambiguous[1]))
# Out:
# The most ambiguous stem is 'respect' with words {'respected', 'respectable', 'respective', 'respectably', 'respects', 'respectability', 'Respect', 'respectful', 'respect', 'respectfully', 'respecting'}
